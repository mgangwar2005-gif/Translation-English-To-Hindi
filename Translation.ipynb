# %% [markdown]
# <a href="https://colab.research.google.com/github/mgangwar2005-gif/Translation-English-To-Hindi/blob/main/Translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Welcome in Google collab')
# Out:
# Welcome in Google collab

# %%
#Create Language translation using Hugginf face for Transformers
from transformers import MarianMTModel, MarianTokenizer
#TO Select the model name from hugging face from transformers
model_name = 'Helsinki-NLP/opus-mt-en-hi'
#TO load the model using model name
model = MarianMTModel.from_pretrained(model_name)
#TO load the tokenizer using model name
tokenizer = MarianTokenizer.from_pretrained(model_name)
#TO get the input from user  to translate
prompt = input('Enter the text to translate ')
#TO encode the input text into input token using tokenizer
input_tokens = tokenizer(prompt, return_tensors = 'pt',padding =True )
#TO generate the output tokens using model and input tokens
output_tokens=model.generate(**input_tokens)
# TO decode the output tokens into tanslated text
print(tokenizer.decode(output_tokens[0], skip_special_tokens=True))

#Upload the code to github
